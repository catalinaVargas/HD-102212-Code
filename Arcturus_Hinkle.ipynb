# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
data1 = np.loadtxt("drive/MyDrive/Fisica/Datos/Arcturus.txt")
datos = data1
x = datos[:,0]
y = datos[:,1]
plt.plot(x,y,c = '#008a35')

# %%
plt.plot(x[2150:2300], y[2150:2300])
plt.axvline(x=7400.179, linestyle='--',c='r', label='7400.179' )
plt.axhline(y =0.9, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[2350:2450], y[2350:2450])
plt.axvline(x=7401.6826, linestyle='--',c='#00ff1e', label='7401.6826' )
plt.xlabel("Longitud de onda Å ")
plt.ylabel("Flujo (Unidades arbitrarias)")
#plt.title("Líneas espectrales")
plt.axhline(y =0.93, linestyle='--',c='#00ff1e')
plt.legend()

# %%
plt.plot(x[3400:3550], y[3400:3550])
plt.axvline(x=7411.1526, linestyle='--',c='#00ff1e', label='7411.1526' )
plt.axhline(y =0.93, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[4200:4440], y[4200:4440])
plt.axvline(x=7418.6662, linestyle='--',c='#00ff1e', label="7418.6662" )
plt.axhline(y =0.93, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[4910:5050], y[4910:5050])
plt.axvline(x=7424.5858, linestyle='--',c='#fc03b6', label="7424.5858" )
plt.axhline(y =0.94, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[5659:5700], y[5659:5700])
plt.axvline(x=7430.8555, linestyle='--',c='#00ff1e', label="7430.8555" )
plt.axhline(y =0.91, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[5850:5920], y[5850:5920])
plt.axvline(x=7432.6704, linestyle='--',c='#fc03b6', label="7432.6704" )
plt.axhline(y =0.93, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[6780:6850], y[6780:6850])
plt.axvline(x=7440.911, linestyle='--',c='#00ff1e' , label="7440.911")
plt.axhline(y =0.89, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[6980:7090], y[6980:7090])
plt.axvline(x=7443.0217, linestyle='-',c='#00ff1e', label ='7443.0217' )
plt.axhline(y =0.91, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[6740:6790], y[6740:6790])
plt.axvline(x=7440.5765, linestyle='--',c='#fc03b6' , label="7440.5765")
plt.axhline(y =0.89, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[9100:9200], y[9100:9200])
plt.axvline(x=7462.309, linestyle='--',c='r' , label="7462.309")
plt.axhline(y =0.93, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[7300:7400], y[7300:7400])
plt.axvline(x=7445.7485, linestyle='--',c='#00ff1e' , label="7445.7485")
plt.axhline(y =0.9, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[8100:8300], y[8100:8300])
plt.axhline(y =0.975, linestyle='--',c='#00ff1e')
plt.axvline(x=7453.9966, linestyle='--',c='#00ff1e' , label="7453.9966")

# %%
plt.plot(x[8450:8550], y[8450:8550])
plt.axvline(x=7456.5841, linestyle='--',c='#fc03b6' , label="7456.5841")
plt.axhline(y =0.943, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[9000:9100], y[9000:9100])
plt.axvline(x=7461.5194, linestyle='--',c='#00ff1e' , label="7461.5194")
plt.axhline(y =0.92, linestyle='--',c='#00ff1e')

# %%
plt.axvline(x=7489.578, linestyle='--',c='#fc03b6' , label="7489,578")
plt.plot(x[12100:12200], y[12100:12200])
plt.axhline(y =0.923, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[12320:12400], y[12320:12400])
plt.axvline(x=7491.6468, linestyle='--',c='#00ff1e' , label="7491.6468")
plt.axhline(y =0.85, linestyle='--',c='#00ff1e')

# %%
plt.scatter(x[9900:10100], y[9900:10100])
plt.axhline(y =0.935, linestyle='--',c='#00ff1e')
plt.axvline(x=7469.938, linestyle='--',c='#fc03b6' , label="7469.938")

# %%
plt.plot(x[10090:10170], y[10090:10170])
plt.axvline(x=7471.2131, linestyle='--',c='#fc03b6' , label="7471.2131")
plt.axhline(y =0.965, linestyle='--',c='#00ff1e')

# %%
plt.scatter(x[10645:10700], y[10645:10700])
plt.axvline(x=7476.3747, linestyle='--',c='#00ff1e' , label="7476.3747")
plt.axhline(y =0.92, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[10495:10590], y[10495:10590])
plt.axvline(x=7474.8944, linestyle='--',c='#fc03b6' , label="7474.8944")
plt.axhline(y =0.92, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[12700:12800], y[12700:12800])
plt.axvline(x=7495.0651, linestyle='--',c='#00ff1e' , label="7495.0651")
plt.axhline(y =0.75, linestyle='--',c='#00ff1e')

# %%
plt.scatter(x[13100:13200], y[13100:13200])
plt.axvline(x=7498.5298, linestyle='--',c='#00ff1e' , label="7498.5298")
plt.axhline(y =0.94, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[12800:13000], y[12800:13000])
plt.axvline(x=7496.102, linestyle='--',c='#fc03b6' , label="7496.102")
plt.axhline(y =0.945, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[10350:10450], y[10350:10450])
plt.axvline(x=7473.5538, linestyle='--',c='#00ff1e' , label="7473.5538")
plt.axhline(y =0.96, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[7500:7580], y[7500:7580])
plt.axvline(x=7447.3931, linestyle='--',c='#00ff1e' , label="7447.3931")#
plt.axhline(y =0.935, linestyle='--',c='#00ff1e')
