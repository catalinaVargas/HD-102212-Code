# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import math
from google.colab import drive
from scipy.signal import find_peaks
#plt.style.use('dark_background')

# %%
data1 = pd.read_csv("drive/My Drive/Fisica/Datos/hd102212.txt",sep ="   " ,header=None)
datos = data1.to_numpy()
x = datos[:,0]
y = datos[:,1]
print(x)
print(y)
plt.plot(x,y/np.max(y))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# [7400.016 7400.036 7400.057 ... 7499.93  7499.95  7499.971]
# [5997.7438 5985.3302 5979.4924 ... 5242.6028 5300.0775 5354.078 ]

# %%
picos =[]
for i in range(len(x)):
  if i ==0:
    if y[i] < y[i+1]:
      picos.append(x[i])
    elif i == len(x)-1:
      if y[i] < y[i-1]:
        picos.append(x[i])
    else:
      if y[i] < y[i+1] and y[i] < y[i-1]:
        picos.append(x[i])
print(picos)
# Out:
# []

# %%
peaks, _ = find_peaks(y)
#plt.plot(peaks, x[peaks], "x")

plt.plot(x[80:550],y[80:550])
plt.title("HD 102212")
plt.xlabel(r'Longitud de onda Å')
plt.ylabel(r'Flujo (Unidades arbitrarias)')
#plt.axvline(x= 7420.202, linestyle='--',c='r')
np.argmin(y[800:1000])
print(x[120])
plt.savefig('espec.pdf')
# Out:
# 7402.453

# %%
lineas_hierro = np.array([7401.478,7403.001,7403.996,7405.316, 7407.083,7412.465, 7413.582, 7414.313, 7415.815, 7417.257, 7418.293, 7418.699, 7422.862,7423.593,7424.507,7424.832,7425.888,7426.578,7427.858,7431.858,7432.143, 7434.011,7434.641,7435.879,7436.874,7438.438,7438.926,7441.18,7444.327,7444.2724,7449.4849,7453.425,7454.217,7455.334,7457.917,7458.665,7463.66,7471.276,7472.535,7473.083,7474.911,7476.251,7476.84,7478.911,7490.913,7497.432])

# %%
max = np.max(y)
plt.plot(x[130:160], y[130:160]/max,  c="#1800c9" )
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7401.6844+1.3, linestyle='--',c='r')
plt.axhline(y= 0.90, linestyle='--')

# %%
plt.plot(x[590:640], y[590:640]/max,  c="#1800c9" )
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7411.1539+1.3, linestyle='--',c='r')
plt.axhline(y= 0.90, linestyle='--')

# %%
plt.axvline(x= 7418.6670, linestyle='--',c='r')
plt.plot(x[905:940], y[905:940]/max,  c="#1800c9" )
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axhline(y= 0.79, linestyle='--')

# %%
plt.axvline(x= 7430.8567+1.3, linestyle='--',c='r')
plt.plot(x[1574:1600], y[1574:1600]/max,  c="#1800c9" )
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axhline(y= 0.85, linestyle='--')

# %%
plt.axvline(x= 7440.9122+1.3, linestyle='--',c='r')
plt.plot(x[2068:2090], y[2068:2090]/max,  c="#1800c9" )
plt.axhline(y= 0.79, linestyle='--')

# %%
plt.axvline(x= 7443.0224+1.3, linestyle='--',c='r')
plt.plot(x[2160:2200], y[2160:2200]/max,  c="#1800c9" )
plt.axhline(y= 0.89, linestyle='--')

# %%
#lineas_hierro = np.array([7401.478, 7407.083, 7417.257, 7418.699 ,7422.862, 7435.879,7463.66,7471.276,7472.535,7473.083,7474.911,7476.251,7476.84,7497.432])

# %%
plt.axvline(x= 7445.7508+1.3, linestyle='--',c='r')
plt.plot(x[2290:2350], y[2290:2350]/max,  c="#1800c9" )
plt.axhline(y= 0.85, linestyle='--')

# %%
plt.axvline(x= 7447.3938+1.3, linestyle='--',c='r')
plt.plot(x[2380:2420], y[2380:2420]/max,  c="#1800c9" )
plt.axhline(y= 0.91, linestyle='--')

# %%
plt.axvline(x= 7461.5206+1.3, linestyle='--',c='r')
plt.plot(x[3070:3110], y[3070:3110]/max,  c="#1800c9" )
plt.axhline(y= 0.87, linestyle='--')

# %%
plt.axvline(x= 7473.5539+1.3, linestyle='--',c='r')
plt.plot(x[3670:3710], y[3670:3710]/max,  c="#1800c9" )
plt.axhline(y= 0.937, linestyle='--')

# %%
plt.axvline(x= 7476.3759+1.3, linestyle='--',c='r')
plt.plot(x[3819:3830], y[3819:3830]/max,  c="#1800c9" )
plt.axhline(y= 0.89, linestyle='--')

# %%
plt.axvline(x= 7481.9326+1.3, linestyle='--',c='r')
plt.plot(x[4059:4130], y[4059:4130]/max,  c="#1800c9" )

# %%
plt.axvline(x= 7482.2232+1.3, linestyle='--',c='r')
plt.plot(x[4059:4130], y[4059:4130]/max,  c="#1800c9" )

# %%
plt.axvline(x= 7491.6486+1.3, linestyle='--',c='r')
plt.plot(x[4570:4585], y[4570:4585]/max,  c="#1800c9" )
plt.axhline(y= 0.73, linestyle='--')

# %%
plt.axvline(x= 7495.0674+1.3, linestyle='--',c='r')
plt.plot(x[4732:4770], y[4732:4770]/max,  c="#1800c9" )
plt.axhline(y= 0.69, linestyle='--')

# %%
plt.plot(x[80:1000], y[80:1000],  c="#1800c9" )
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7401.6844, linestyle='--',c='r')
plt.axvline(x= 7411.1539, linestyle='--',c='r')
plt.axvline(x= 7418.6670, linestyle='--',c='r')
plt.legend()
plt.savefig('esp1f8')
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(x[10:1050],y[10:1050],c='#1800c9')
corrimiento = np.array([7401.6844 , 7411.1539, 7418.6670])
print(corrimiento+1.3)
corrimiento += 1.3

for i in corrimiento:
 plt.axvline(x= i, linestyle='--',c='r')
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.legend()
plt.savefig('dopp')
# Out:
# No handles with labels found to put in legend.
# [7402.9844 7412.4539 7419.967 ]

# %%
#print(np.where(x > 7405.0))
plt.plot(x[210:450],y[210:450])
plt.axvline(x=7407.083,linestyle='--' )
plt.axvline(x=7405.296,linestyle='--')
peaks, _ = find_peaks(x[210:450])
plt.plot(peaks, x[peaks], "x")

print(peaks)
# Out:
# []

# %%
plt.plot(x[450:750],y[450:750])
plt.axvline(x=7412.465,linestyle='--' )
plt.axvline(x=7413.582,linestyle='--' )
plt.axvline(x=7414.313,linestyle='--' )

# %%
plt.plot(x[550:950],y[550:950])
plt.axvline(x=7415.815,linestyle='--' )
plt.axvline(x=7417.265,linestyle='--' )
#plt.axvline(x=7414.313,linestyle='--' )
plt.axvline(x= 7411.1539, linestyle='--',c='r')
plt.axvline(x= 7418.6670, linestyle='--',c='r')

# %%
plt.plot(x[950:1200],y[950:1200])
plt.axvline(x=7419.978,linestyle='--' )
plt.axvline(x=7422.870,linestyle='--' )
plt.axvline(x=7423.593,linestyle='--' )

# %%
plt.plot(x[1180:1400],y[1180:1400])
plt.axvline(x=7425.898,linestyle='--' )
plt.axvline(x=7426.578,linestyle='--' )
plt.axvline(x=7427.858,linestyle='--' )
piquitos = y[11800:1400]
peaks, _ = find_peaks(piquitos)
plt.plot(peaks, piquitos[peaks], c='r')
plt.show()

# %%
plt.plot(x[1400:1700],y[1400:1700])
plt.axvline(x=7432.955,linestyle='--' )
plt.axvline(x=7433.991,linestyle='--' )

# %%
plt.plot(x[1680:1910],y[1680:1910])
plt.axvline(x=7434.661,linestyle='--' )
plt.axvline(x=7436.895,linestyle='--' )
plt.axvline(x=7438.438,linestyle='--' )

# %%
plt.plot(x[1900:2200],y[1900:2200])
plt.axvline(x=7441.181,linestyle='--' )
plt.axvline(x=7444.327,linestyle='--' )

# %%
plt.plot(x[2700:3000],y[2700:3000])
plt.axvline(x=7455.314,linestyle='--' )
plt.axvline(x=7457.913,linestyle='--' )
plt.axvline(x=7457.304,linestyle='--' )
plt.axvline(x=7458.665,linestyle='--' )

# %%
plt.plot(x[2700:3970],y[2700:3970])
plt.axvline(x=7477.6754, linestyle='--',c='r')
print(np.min(y[3650:3700]))
print(np.where(y==5256.6667))
print(x[3686])
corrimiento = np.array([7461.5201, 7473.5535 , 7476.3754])
print(corrimiento+1.3)
corrimiento += 1.3
#0.22
#for i in corrimiento:
 # plt.axvline(x= i, linestyle='--',c='r')
# [7462.8201 7474.8535 7477.6754]
#***********************líneas de hierro 7462.828 ******************************
#*********************** líneas de hierro 7474.87 ********************************
# Out:
# 5256.6667
# (array([3686]),)
# 7474.87
# [7462.8201 7474.8535 7477.6754]

# %%
plt.plot(x[3450:3800],y[3450:3800])
plt.axvline(x=7471.255,linestyle='--' )
plt.axvline(x=7472.535,linestyle='--' )
plt.axvline(x=7473.063,linestyle='--' )
plt.axvline(x=7474.891,linestyle='--' )
plt.axvline(x=7476.211,linestyle='--' )
plt.axvline(x=7476.799,linestyle='--' )

# %%
plt.plot(x[3800:4100],y[3800:4100])
plt.axvline(x=7478.871,linestyle='--' )

# %%
plt.plot(x[4100:4500],y[4100:4500])
plt.axvline(x=7490.873,linestyle='--' )

# %%
plt.plot(x[2900:7700],y[2900:7700])
#corrimiento = np.array([ 7491.6481,7495.0670,7498.5300 ])
#print(corrimiento+1.3)
plt.axvline(x= 7492.964, linestyle='--',c='r')
print(np.min(y[4700:4800]))
print(np.where(y == 2727.4771))
print(x[4746])
plt.axvline(x= 7492.964, linestyle='--',c='r')
corrimiento += 1.3
#0.22
for i in corrimiento:
  plt.axvline(x= i, linestyle='--',c='r')
#[7492.9481 7496.367  7499.83  ]
#************** lineas de hierro 7492.964 **************
#**************** lineas de hierro 7496.396 *************
# Out:
# 2727.4771
# (array([4746]),)
# 7496.396
