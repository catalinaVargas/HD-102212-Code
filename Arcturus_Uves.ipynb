# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import math
from google.colab import drive
from scipy.signal import find_peaks

# %%
datos = np.loadtxt("/content/drive/MyDrive/Fisica/Datos/Arcturus_UVES.txt")
x = datos[:,0]
y = datos[:,1]

# %%
plt.plot(x[10:90],y[10:90])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7400.179, linestyle='--',c='r')
plt.axhline(y =0.84, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[90:150],y[90:150])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7401.6826, linestyle='--',c='r')
plt.axhline(y =0.915, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[550:650],y[550:650])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x=  7411.1526, linestyle='--',c='r')
plt.axhline(y =0.843, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[910:1050],y[910:1050])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x=  7418.6662, linestyle='--',c='r')
plt.axhline(y =0.9, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[1245:1280],y[1245:1280])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x=  7424.5858, linestyle='--',c='r')
plt.axhline(y =0.925, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[1555:1575],y[1555:1575])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7430.8555, linestyle='--',c='r')
plt.axhline(y =0.87, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[1645:1665],y[1645:1665])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7432.6704, linestyle='--',c='r')
plt.axhline(y =0.94, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[2050:2080],y[2050:2080])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7440.911, linestyle='--',c='r')
plt.axhline(y =0.843, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[2140:2180],y[2140:2180])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7443.0217, linestyle='--',c='r')
plt.axhline(y =0.9, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[2030:2055],y[2030:2055])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7440.5765,linestyle='--',c='r')
plt.axhline(y =0.81, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[2350:2395],y[2350:2395])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7447.3931,linestyle='--',c='r')
plt.axhline(y =0.95, linestyle='--',c='#00ff1e')

# %%
 
plt.plot(x[3100:3150],y[3100:3150])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x=  7462.309,linestyle='--',c='r')
plt.axhline(y =0.9, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[2280:2310],y[2280:2310])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7445.7485,linestyle='--',c='r')
plt.axhline(y =0.78, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[2690:2730],y[2690:2730])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7453.9966,linestyle='--',c='r')
plt.axhline(y =0.94, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[2810:2850],y[2810:2850])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7456.5841,linestyle='--',c='r')
plt.axhline(y =0.93, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[3050:3090],y[3050:3090])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7461.5194,linestyle='--',c='r')
plt.axhline(y =0.91, linestyle='--',c='#00ff1e')

# %%
 
plt.plot(x[4400:4500],y[4400:4500])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x=  7489.578,linestyle='--',c='r')
plt.axhline(y =0.905, linestyle='--',c='#00ff1e')

# %%
 
plt.plot(x[4540:4600],y[4540:4600])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x=  7491.6468,linestyle='--',c='r')
plt.axhline(y =0.85, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[3480:3500],y[3480:3500])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x=  7469.938,linestyle='--',c='r')
plt.axhline(y =0.925, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[3530:3570],y[3530:3570])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7471.2131,linestyle='--',c='r')
plt.axhline(y =0.955, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[3799:3820],y[3799:3820])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7476.3747,linestyle='--',c='r')
plt.axhline(y =0.92, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[3720:3750],y[3720:3750])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7474.8944,linestyle='--',c='r')
plt.axhline(y =0.92, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[4710:4740],y[4710:4740])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7495.0651,linestyle='--',c='r')
plt.axhline(y =0.75, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[4890:4910],y[4890:4910])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x= 7498.5298,linestyle='--',c='r')
plt.axhline(y =0.88, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[4750:4800],y[4750:4800])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x=7496.102,linestyle='--',c='r')
plt.axhline(y =0.94, linestyle='--',c='#00ff1e')

# %%
plt.plot(x[3650:3700],y[3650:3700])
plt.xlabel('Longitud de onda Å')
plt.ylabel('Flujo (Unidades arbitrarias)')
plt.axvline(x=7473.5538,linestyle='--',c='r')
plt.axhline(y =0.96, linestyle='--',c='#00ff1e')
